# %%
#Write code that selects the:
    #First name
    #Last name
    #Year columns
students = {'FIRST_NAME' : ['Daniel', 'Ben', 'Kavita', 'Linda', 'Omar', 'Jane', 'Felicia', 'Rachel', 'Bob'],
            'LAST_NAME'  : ['Smith', 'Leibstrom', 'Kanabar', 'Thiel', 'Reichel', 'OConner', 'Rao', 'Crock', 'McDonald'],
            'YEAR' : [1, 1, 1, 4, 2, 2, 3, 1, 1],
            'HOME_STATE' : ['NY', 'NY', 'PA', 'CA', 'OK', 'HI', 'NY', 'FL', 'FL'],
            'AGE' : [18, 19, 19, 22, 21, 19, 20, 17, 18],
            'CALC_101_FINAL' : [90, 80, None, 60, 70, None, None, None, 98],
            'ENGLISH_101_FINAL' : [80, None, None, 40, 50, None, None, 60, 65]}

# %%
import pandas as pd

# %%
print(students)
# Out:
# {'FIRST_NAME': ['Daniel', 'Ben', 'Kavita', 'Linda', 'Omar', 'Jane', 'Felicia', 'Rachel', 'Bob'], 'LAST_NAME': ['Smith', 'Leibstrom', 'Kanabar', 'Thiel', 'Reichel', 'OConner', 'Rao', 'Crock', 'McDonald'], 'YEAR': [1, 1, 1, 4, 2, 2, 3, 1, 1], 'HOME_STATE': ['NY', 'NY', 'PA', 'CA', 'OK', 'HI', 'NY', 'FL', 'FL'], 'AGE': [18, 19, 19, 22, 21, 19, 20, 17, 18], 'CALC_101_FINAL': [90, 80, None, 60, 70, None, None, None, 98], 'ENGLISH_101_FINAL': [80, None, None, 40, 50, None, None, 60, 65]}

# %%
df_students = pd.DataFrame(students)
df_students
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
# 5       Jane    OConner     2         HI   19             NaN
# 6    Felicia        Rao     3         NY   20             NaN
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0

# %%
df_students['FIRST_NAME']
# Out:
# 0     Daniel
# 1        Ben
# 2     Kavita
# 3      Linda
# 4       Omar
# 5       Jane
# 6    Felicia
# 7     Rachel
# 8        Bob
# Name: FIRST_NAME, dtype: object

# %%
df_students['LAST_NAME']
# Out:
# 0        Smith
# 1    Leibstrom
# 2      Kanabar
# 3        Thiel
# 4      Reichel
# 5      OConner
# 6          Rao
# 7        Crock
# 8     McDonald
# Name: LAST_NAME, dtype: object

# %%
df_students['YEAR']
# Out:
# 0    1
# 1    1
# 2    1
# 3    4
# 4    2
# 5    2
# 6    3
# 7    1
# 8    1
# Name: YEAR, dtype: int64

# %%
#Upload items.csv & restaurants.csv
#Read into Pandas
#Put them in df_items and df_restaurants
#DataFrames
# Show the first rows of the files
# Figure out the number of lines loaded
df_items = pd.read_csv('items.csv')
df_items.head()
# Out:
#   ITEM_ID                               ITEM_NAME ITEM_TYPE
# 0      I0              Charred Chicken Marketbowl     Mains
# 1      I1              Spicy Meatballs Marketbowl     Mains
# 2      I2         Grilled Organic Tofu Marketbowl     Mains
# 3      I3         Herb Roasted Chicken Marketbowl     Mains
# 4      I4  Roasted Wild Alaskan Salmon Marketbowl     Mains

# %%
df_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 3 columns):
# ITEM_ID      31 non-null object
# ITEM_NAME    31 non-null object
# ITEM_TYPE    31 non-null object
# dtypes: object(3)
# memory usage: 872.0+ bytes

# %%
df_restaurants = pd.read_csv('restaurants.csv')
df_restaurants.head()
# Out:
#   RESTAURANT_ID         NAME                               ADDRESS        LAT  \
# 0        R10001     Columbia     2884 Broadway, New York, NY 10025  40.811470
# 1        R10002      Midtown      1379 6th Ave, New York, NY 10019  40.763640
# 2        R10003  Bryant Park      70 W 40th St, New York, NY 10018  40.752911
# 3        R10005     Flatiron      40 W 25th St, New York, NY 10010  40.743600
# 4        R10004          NYU  109 Macdougal St, New York, NY 10012  40.729930
#
#         LONG OPENING_DATE DELIVERY_START
# 0 -73.961230     8/9/2014     2017-01-01
# 1 -73.977960    3/19/2013     2018-05-01
# 2 -73.983498    5/21/2013     2018-05-01
# 3 -73.991070   11/14/2013     2016-03-05
# 4 -74.000820    1/10/2014     2017-01-01

# %%
df_restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
# RESTAURANT_ID     8 non-null object
# NAME              8 non-null object
# ADDRESS           8 non-null object
# LAT               8 non-null float64
# LONG              8 non-null float64
# OPENING_DATE      8 non-null object
# DELIVERY_START    8 non-null object
# dtypes: float64(2), object(5)
# memory usage: 576.0+ bytes

# %%
# number of row
df_restaurants.shape[0]
# Out:
# 8

# %%
# Change the necessary columns in the
# df_restaurants DataFrame

df_restaurants.OPENING_DATE = pd.to_datetime(df_restaurants.OPENING_DATE)
df_restaurants.head
# Out:
# <bound method NDFrame.head of   RESTAURANT_ID             NAME                                 ADDRESS  \
# 0        R10001         Columbia       2884 Broadway, New York, NY 10025
# 1        R10002          Midtown        1379 6th Ave, New York, NY 10019
# 2        R10003      Bryant Park        70 W 40th St, New York, NY 10018
# 3        R10005         Flatiron        40 W 25th St, New York, NY 10010
# 4        R10004              NYU    109 Macdougal St, New York, NY 10012
# 5        R10006  Upper East Side  1045 Lexington Ave, New York, NY 10021
# 6        R10007  Upper West Side       2140 Broadway, New York, NY 10023
# 7        R10008     Williamsburg         45 S 3rd St, Brooklyn, NY 11249
#
#          LAT       LONG OPENING_DATE DELIVERY_START
# 0  40.811470 -73.961230   2014-08-09     2017-01-01
# 1  40.763640 -73.977960   2013-03-19     2018-05-01
# 2  40.752911 -73.983498   2013-05-21     2018-05-01
# 3  40.743600 -73.991070   2013-11-14     2016-03-05
# ...

# %%
df_restaurants.DELIVERY_START = pd.to_datetime(df_restaurants.DELIVERY_START)

# %%
#Challenge:
#1. Analyse numerical columns in the
#df_orders DataFrame
df_orders = pd.read_csv('simplified_orders.csv')
df_orders
# Out:
#          ORDER_ID             DATETIME RESTAURANT_ID      TYPE  DRINKS  \
# 0        O2226026  2018-12-07 19:17:45        R10001    PICKUP     2.0
# 1        O1279827  2018-07-14 21:23:43        R10006  IN_STORE     0.0
# 2         O689957  2018-04-12 13:14:42        R10002    PICKUP     0.0
# 3        O1497863  2018-08-21 18:14:23        R10007  IN_STORE     1.0
# 4        O1443303  2018-08-12 18:04:44        R10006  DELIVERY     0.0
# ...           ...                  ...           ...       ...     ...
# 2392361  O1954914  2018-10-30 16:50:33        R10006  IN_STORE     0.0
# 2392362  O1241052  2018-07-08 10:47:37        R10001  IN_STORE     0.0
# 2392363    O28030  2018-01-05 17:07:01        R10005  IN_STORE     0.0
# 2392364   O277869  2018-02-12 11:18:33        R10005  IN_STORE     3.0
# 2392365   O773630  2018-04-24 17:19:51        R10007  IN_STORE     0.0
#
#          COOKIES MAIN BASE SIDE_1 SIDE_2
# 0            2.0  NaN  NaN    NaN    NaN
# ...

# %%
df_orders.TYPE.value_counts()
# Out:
# IN_STORE    1718673
# PICKUP       400663
# DELIVERY     273030
# Name: TYPE, dtype: int64

# %%
df_orders.COOKIES.describe()
# Out:
# count    2.392366e+06
# mean     2.602909e-01
# std      5.589882e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.000000e+00
# Name: COOKIES, dtype: float64

# %%
#2. Plot a histogram of median household
#incomes of all MSAs in our census
#dataset and interpret the outcome
df_census = pd.read_csv('census.csv')
df_census
# Out:
#       FIPS                                     Geography  2017 Population  \
# 0    10100                       Aberdeen, SD Micro Area            42608
# 1    10140                       Aberdeen, WA Micro Area            71454
# 2    10180                        Abilene, TX Metro Area           169000
# 3    10220                            Ada, OK Micro Area            38289
# 4    10300                         Adrian, MI Micro Area            98585
# ..     ...                                           ...              ...
# 928  49660  Youngstown-Warren-Boardman, OH-PA Metro Area           548821
# 929  49700                      Yuba City, CA Metro Area           170227
# 930  49740                           Yuma, AZ Metro Area           204281
# 931  49780                     Zanesville, OH Micro Area            85933
# 932  49820                         Zapata, TX Micro Area            14415
#
#      2017 Median Age  2017 Total households  2017 Median HHIncome  \
# ...

# %%
df_census.Geography.value_counts()
# Out:
# Rexburg, ID Micro Area                              1
# Fayetteville-Springdale-Rogers, AR-MO Metro Area    1
# Clinton, IA Micro Area                              1
# Frankfort, KY Micro Area                            1
# Owosso, MI Micro Area                               1
#                                                    ..
# Bogalusa, LA Micro Area                             1
# Ocala, FL Metro Area                                1
# Natchitoches, LA Micro Area                         1
# Green Bay, WI Metro Area                            1
# Las Vegas, NM Micro Area                            1
# Name: Geography, Length: 933, dtype: int64

# %%
df_census = df_census.rename(columns = {'2017 Median HHIncome': 'Median_HH_income'})
df_census
# Out:
#       FIPS                                     Geography  2017 Population  \
# 0    10100                       Aberdeen, SD Micro Area            42608
# 1    10140                       Aberdeen, WA Micro Area            71454
# 2    10180                        Abilene, TX Metro Area           169000
# 3    10220                            Ada, OK Micro Area            38289
# 4    10300                         Adrian, MI Micro Area            98585
# ..     ...                                           ...              ...
# 928  49660  Youngstown-Warren-Boardman, OH-PA Metro Area           548821
# 929  49700                      Yuba City, CA Metro Area           170227
# 930  49740                           Yuma, AZ Metro Area           204281
# 931  49780                     Zanesville, OH Micro Area            85933
# 932  49820                         Zapata, TX Micro Area            14415
#
#      2017 Median Age  2017 Total households  Median_HH_income  \
# ...

# %%
df_census.Median_HH_income.describe()
# Out:
# count       933.000000
# mean      50048.757771
# std       10546.088833
# min       23558.000000
# 25%       43310.000000
# 50%       49052.000000
# 75%       54882.000000
# max      110190.000000
# Name: Median_HH_income, dtype: float64

# %%
import matplotlib.pyplot as plt
# visualization library
#df_census.Median_HH_income.value_counts(normalize = True).plot(kind = 'bar')
plt.hist(df_census.Median_HH_income, bins = [20000, 40000, 60000, 80000, 100000, 120000])
plt.ylabel('Counts')
plt.xlabel('2017 Median HHIncome')
plt.title('Histogram of median household incomes of all MSAs')
plt.show()

# %%
# #Determine if the Metropolitan statistical
# areas (MSA) for each row in the census
# data has a population of between 20,000
# and 60,000
((df_census['2017 Population'] >=20000) & (df_census['2017 Population'] >=60000)).head
# Out:
# <bound method NDFrame.head of 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 928     True
# 929     True
# 930     True
# 931     True
# 932    False
# Name: 2017 Population, Length: 933, dtype: bool>

# %%
# Find the proportion of orders with no bowls
df_orders
# Out:
#          ORDER_ID             DATETIME RESTAURANT_ID      TYPE  DRINKS  \
# 0        O2226026  2018-12-07 19:17:45        R10001    PICKUP     2.0
# 1        O1279827  2018-07-14 21:23:43        R10006  IN_STORE     0.0
# 2         O689957  2018-04-12 13:14:42        R10002    PICKUP     0.0
# 3        O1497863  2018-08-21 18:14:23        R10007  IN_STORE     1.0
# 4        O1443303  2018-08-12 18:04:44        R10006  DELIVERY     0.0
# ...           ...                  ...           ...       ...     ...
# 2392361  O1954914  2018-10-30 16:50:33        R10006  IN_STORE     0.0
# 2392362  O1241052  2018-07-08 10:47:37        R10001  IN_STORE     0.0
# 2392363    O28030  2018-01-05 17:07:01        R10005  IN_STORE     0.0
# 2392364   O277869  2018-02-12 11:18:33        R10005  IN_STORE     3.0
# 2392365   O773630  2018-04-24 17:19:51        R10007  IN_STORE     0.0
#
#          COOKIES MAIN BASE SIDE_1 SIDE_2
# 0            2.0  NaN  NaN    NaN    NaN
# ...

# %%
df_items
# Out:
#    ITEM_ID                               ITEM_NAME     ITEM_TYPE
# 0       I0              Charred Chicken Marketbowl         Mains
# 1       I1              Spicy Meatballs Marketbowl         Mains
# 2       I2         Grilled Organic Tofu Marketbowl         Mains
# 3       I3         Herb Roasted Chicken Marketbowl         Mains
# 4       I4  Roasted Wild Alaskan Salmon Marketbowl         Mains
# 5       I5                      Classic Brown Rice         Bases
# 6       I6                   Farm Greens with Mint         Bases
# 7       I7            Farro with Summer Vegetables         Bases
# 8       I8    Cauliflower with Garlic and Parmesan  Market Sides
# 9       I9                Jasper Hill Mac & Cheese  Market Sides
# 10     I10                  Roasted Sweet Potatoes  Market Sides
# 11     I11             Charred Broccoli with Lemon  Market Sides
# 12     I12                      Cashew Kale Caesar  Market Sides
# ...

# %%
df_orders.MAIN.isnull().sum() / df_orders.shape[0]
# Out:
# 0.050849242967004216

# %%
# 1.Plot a bar graph with weekday orders!
# X axis = weekdays
# Y axis = orders
df_orders.head()
# Out:
#    ORDER_ID            DATETIME RESTAURANT_ID      TYPE  DRINKS  COOKIES MAIN  \
# 0  O2226026 2018-12-07 19:17:45        R10001    PICKUP     2.0      2.0  NaN
# 1  O1279827 2018-07-14 21:23:43        R10006  IN_STORE     0.0      0.0  NaN
# 2   O689957 2018-04-12 13:14:42        R10002    PICKUP     0.0      2.0   I1
# 3  O1497863 2018-08-21 18:14:23        R10007  IN_STORE     1.0      0.0   I1
# 4  O1443303 2018-08-12 18:04:44        R10006  DELIVERY     0.0      0.0   I1
#
#   BASE SIDE_1 SIDE_2
# 0  NaN    NaN    NaN
# 1  NaN    NaN    NaN
# 2   I7    I11     I8
# 3   I5    I10     I9
# 4   I6    I10    I11

# %%
df_orders.DATETIME = pd.to_datetime(df_orders.DATETIME)
df_orders.DATETIME.dt.weekday
# Out:
# 0          4
# 1          5
# 2          3
# 3          1
# 4          6
#           ..
# 2392361    1
# 2392362    6
# 2392363    4
# 2392364    0
# 2392365    1
# Name: DATETIME, Length: 2392366, dtype: int64

# %%
df_orders.DATETIME.dt.weekday.value_counts().plot(kind = 'bar')
plt.ylabel('Counts of order')
plt.xlabel('Weekday')
plt.title('Weekdays order in the restaurant')
plt.show()

# %%
# Find all orders that happened on:
# 2018 – 06 - 01
(df_orders.DATETIME >= '2018-06-01').sum()
# Out:
# 1372023

# %%
# Find all orders that happened on:
# 2018 – 06 - 01
(df_orders.DATETIME >= '2018-06-01').sum()

# %%
# Find all orders that happened on:
# 2018 – 06 - 01
(df_orders.DATETIME >= '2018-06-01').sum()
