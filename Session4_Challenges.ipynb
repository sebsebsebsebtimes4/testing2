# %%
#Challenge1:

#Write code that selects the:
    #First name
    #Last name
    #Year columns

# %%
students = {'FIRST_NAME' : ['Daniel', 'Ben', 'Kavita', 'Linda', 'Omar', 'Jane', 'Felicia', 'Rachel', 'Bob'],
            'LAST_NAME'  : ['Smith', 'Leibstrom', 'Kanabar', 'Thiel', 'Reichel', 'OConner', 'Rao', 'Crock', 'McDonald'],
            'YEAR' : [1, 1, 1, 4, 2, 2, 3, 1, 1],
            'HOME_STATE' : ['NY', 'NY', 'PA', 'CA', 'OK', 'HI', 'NY', 'FL', 'FL'],
            'AGE' : [18, 19, 19, 22, 21, 19, 20, 17, 18],
            'CALC_101_FINAL' : [90, 80, None, 60, 70, None, None, None, 98],
            'ENGLISH_101_FINAL' : [80, None, None, 40, 50, None, None, 60, 65]}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab

# %%
df_students = pd.DataFrame(students)
df_students
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
# 5       Jane    OConner     2         HI   19             NaN
# 6    Felicia        Rao     3         NY   20             NaN
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0

# %%
df_students[['FIRST_NAME', 'LAST_NAME', 'AGE']]
# Out:
#   FIRST_NAME  LAST_NAME  AGE
# 0     Daniel      Smith   18
# 1        Ben  Leibstrom   19
# 2     Kavita    Kanabar   19
# 3      Linda      Thiel   22
# 4       Omar    Reichel   21
# 5       Jane    OConner   19
# 6    Felicia        Rao   20
# 7     Rachel      Crock   17
# 8        Bob   McDonald   18

# %%
#Challenge2:
#upload items.csv & restaurant.csv
#read into pandas
#put them in df_items and df_restaurants dataframes
#show the first rows of the files
#fugure out the number of lines loaded

# %%
df_orders = pd.read_csv('simplified_orders.csv')
df_orders
# Out:
#          ORDER_ID             DATETIME RESTAURANT_ID      TYPE  DRINKS  \
# 0        O2226026  2018-12-07 19:17:45        R10001    PICKUP     2.0
# 1        O1279827  2018-07-14 21:23:43        R10006  IN_STORE     0.0
# 2         O689957  2018-04-12 13:14:42        R10002    PICKUP     0.0
# 3        O1497863  2018-08-21 18:14:23        R10007  IN_STORE     1.0
# 4        O1443303  2018-08-12 18:04:44        R10006  DELIVERY     0.0
# ...           ...                  ...           ...       ...     ...
# 2392361  O1954914  2018-10-30 16:50:33        R10006  IN_STORE     0.0
# 2392362  O1241052  2018-07-08 10:47:37        R10001  IN_STORE     0.0
# 2392363    O28030  2018-01-05 17:07:01        R10005  IN_STORE     0.0
# 2392364   O277869  2018-02-12 11:18:33        R10005  IN_STORE     3.0
# 2392365   O773630  2018-04-24 17:19:51        R10007  IN_STORE     0.0
#
#          COOKIES MAIN BASE SIDE_1 SIDE_2
# 0            2.0  NaN  NaN    NaN    NaN
# ...

# %%
df_restaurants = pd.read_csv('restaurants.csv')
df_restaurants
# Out:
#   RESTAURANT_ID             NAME                                 ADDRESS  \
# 0        R10001         Columbia       2884 Broadway, New York, NY 10025
# 1        R10002          Midtown        1379 6th Ave, New York, NY 10019
# 2        R10003      Bryant Park        70 W 40th St, New York, NY 10018
# 3        R10005         Flatiron        40 W 25th St, New York, NY 10010
# 4        R10004              NYU    109 Macdougal St, New York, NY 10012
# 5        R10006  Upper East Side  1045 Lexington Ave, New York, NY 10021
# 6        R10007  Upper West Side       2140 Broadway, New York, NY 10023
# 7        R10008     Williamsburg         45 S 3rd St, Brooklyn, NY 11249
#
#          LAT       LONG OPENING_DATE DELIVERY_START
# 0  40.811470 -73.961230     8/9/2014     2017-01-01
# 1  40.763640 -73.977960    3/19/2013     2018-05-01
# 2  40.752911 -73.983498    5/21/2013     2018-05-01
# 3  40.743600 -73.991070   11/14/2013     2016-03-05
# ...

# %%
#Challenge3:
#Change the necessary columns in the df-restaurants data frame

# %%
df_restaurants.OPENING_DATE = pd.to_datetime(df_restaurants.OPENING_DATE)
df_restaurants.DELIVERY_START = pd.to_datetime(df_restaurants.DELIVERY_START)

df_restaurants.head()
# Out:
#   RESTAURANT_ID         NAME                               ADDRESS        LAT  \
# 0        R10001     Columbia     2884 Broadway, New York, NY 10025  40.811470
# 1        R10002      Midtown      1379 6th Ave, New York, NY 10019  40.763640
# 2        R10003  Bryant Park      70 W 40th St, New York, NY 10018  40.752911
# 3        R10005     Flatiron      40 W 25th St, New York, NY 10010  40.743600
# 4        R10004          NYU  109 Macdougal St, New York, NY 10012  40.729930
#
#         LONG OPENING_DATE DELIVERY_START
# 0 -73.961230   2014-08-09     2017-01-01
# 1 -73.977960   2013-03-19     2018-05-01
# 2 -73.983498   2013-05-21     2018-05-01
# 3 -73.991070   2013-11-14     2016-03-05
# 4 -74.000820   2014-01-10     2017-01-01

# %%
#Challange4:
#1. Analyse numeric columns in the df_orders Dataframe
#2. Plot a histogram of mediam household of all MSAs in our census dataset and interpret the outcome

# %%
df_orders.head()
# Out:
#    ORDER_ID             DATETIME RESTAURANT_ID      TYPE  DRINKS  COOKIES  \
# 0  O2226026  2018-12-07 19:17:45        R10001    PICKUP     2.0      2.0
# 1  O1279827  2018-07-14 21:23:43        R10006  IN_STORE     0.0      0.0
# 2   O689957  2018-04-12 13:14:42        R10002    PICKUP     0.0      2.0
# 3  O1497863  2018-08-21 18:14:23        R10007  IN_STORE     1.0      0.0
# 4  O1443303  2018-08-12 18:04:44        R10006  DELIVERY     0.0      0.0
#
#   MAIN BASE SIDE_1 SIDE_2
# 0  NaN  NaN    NaN    NaN
# 1  NaN  NaN    NaN    NaN
# 2   I1   I7    I11     I8
# 3   I1   I5    I10     I9
# 4   I1   I6    I10    I11

# %%
df_orders.RESTAURANT_ID.value_counts()
# Out:
# R10004    433231
# R10002    324439
# R10008    313733
# R10007    283907
# R10005    279839
# R10006    273816
# R10001    253588
# R10003    229813
# Name: RESTAURANT_ID, dtype: int64

# %%
(df_orders.DRINKS >=1).sum()
# Out:
# 352327

# %%
print((df_orders.DRINKS >=1))
# Out:
# 0           True
# 1          False
# 2          False
# 3           True
# 4          False
#            ...
# 2392361    False
# 2392362    False
# 2392363    False
# 2392364     True
# 2392365    False
# Name: DRINKS, Length: 2392366, dtype: bool

# %%
df_census = pd.read_csv('census.csv')
df_census
# Out:
#       FIPS                                     Geography  2017 Population  \
# 0    10100                       Aberdeen, SD Micro Area            42608
# 1    10140                       Aberdeen, WA Micro Area            71454
# 2    10180                        Abilene, TX Metro Area           169000
# 3    10220                            Ada, OK Micro Area            38289
# 4    10300                         Adrian, MI Micro Area            98585
# ..     ...                                           ...              ...
# 928  49660  Youngstown-Warren-Boardman, OH-PA Metro Area           548821
# 929  49700                      Yuba City, CA Metro Area           170227
# 930  49740                           Yuma, AZ Metro Area           204281
# 931  49780                     Zanesville, OH Micro Area            85933
# 932  49820                         Zapata, TX Micro Area            14415
#
#      2017 Median Age  2017 Total households  2017 Median HHIncome  \
# ...

# %%
df_census.columns
# Out:
# Index(['FIPS', 'Geography', '2017 Population', '2017 Median Age',
#        '2017 Total households', '2017 Median HHIncome',
#        '2017 Average household size', '2017 Total families',
#        '2017 Average family size', '2017 Percent owner-occupied housing units',
#        '2017 Percent renter-occupied housing units',
#        '2017 Population 16 years and over',
#        '2017 Unemployment rate (Population 16 years and over)'],
#       dtype='object')

# %%
df_census = df_census.rename(columns = {'2017 Median HHIncome': 'Income'})
df_census = df_census.rename(columns = {'2017 Population': 'Population'})
df_census
# Out:
#       FIPS                                     Geography  Population  \
# 0    10100                       Aberdeen, SD Micro Area       42608
# 1    10140                       Aberdeen, WA Micro Area       71454
# 2    10180                        Abilene, TX Metro Area      169000
# 3    10220                            Ada, OK Micro Area       38289
# 4    10300                         Adrian, MI Micro Area       98585
# ..     ...                                           ...         ...
# 928  49660  Youngstown-Warren-Boardman, OH-PA Metro Area      548821
# 929  49700                      Yuba City, CA Metro Area      170227
# 930  49740                           Yuma, AZ Metro Area      204281
# 931  49780                     Zanesville, OH Micro Area       85933
# 932  49820                         Zapata, TX Micro Area       14415
#
#      2017 Median Age  2017 Total households  Income  \
# 0               37.8                  17907   54533
# ...

# %%
df_census.Geography.value_counts()
# Out:
# Adrian, MI Micro Area                    1
# Bloomington, IN Metro Area               1
# Santa Cruz-Watsonville, CA Metro Area    1
# Thomaston, GA Micro Area                 1
# Maryville, MO Micro Area                 1
#                                         ..
# Big Rapids, MI Micro Area                1
# Shawano, WI Micro Area                   1
# Peoria, IL Metro Area                    1
# Niles-Benton Harbor, MI Metro Area       1
# Clarksville, TN-KY Metro Area            1
# Name: Geography, Length: 933, dtype: int64

# %%
df_census.Income.plot(x='Geography', y='Income', kind = 'bar')

# %%
((df_census.Population >20000) & (df_census.Population <60)).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Population, dtype: bool

# %%
#Challenge5:
#Find the proportion of orders with no bowls

# %%
df_orders.head()
# Out:
#    ORDER_ID             DATETIME RESTAURANT_ID      TYPE  DRINKS  COOKIES  \
# 0  O2226026  2018-12-07 19:17:45        R10001    PICKUP     2.0      2.0
# 1  O1279827  2018-07-14 21:23:43        R10006  IN_STORE     0.0      0.0
# 2   O689957  2018-04-12 13:14:42        R10002    PICKUP     0.0      2.0
# 3  O1497863  2018-08-21 18:14:23        R10007  IN_STORE     1.0      0.0
# 4  O1443303  2018-08-12 18:04:44        R10006  DELIVERY     0.0      0.0
#
#   MAIN BASE SIDE_1 SIDE_2
# 0  NaN  NaN    NaN    NaN
# 1  NaN  NaN    NaN    NaN
# 2   I1   I7    I11     I8
# 3   I1   I5    I10     I9
# 4   I1   I6    I10    I11

# %%
df_orders.BASE.value_counts(normalize = True)
# Out:
# I6    0.452889
# I5    0.348156
# I7    0.198955
# Name: BASE, dtype: float64

# %%
#Challenge6:
#plot a bar graph with weekday orders!
#find all orders that happened on 2018-06-01

# %%
df_orders.DATETIME = pd.to_datetime(df_orders.DATETIME)
df_orders
# Out:
#          ORDER_ID            DATETIME RESTAURANT_ID      TYPE  DRINKS  \
# 0        O2226026 2018-12-07 19:17:45        R10001    PICKUP     2.0
# 1        O1279827 2018-07-14 21:23:43        R10006  IN_STORE     0.0
# 2         O689957 2018-04-12 13:14:42        R10002    PICKUP     0.0
# 3        O1497863 2018-08-21 18:14:23        R10007  IN_STORE     1.0
# 4        O1443303 2018-08-12 18:04:44        R10006  DELIVERY     0.0
# ...           ...                 ...           ...       ...     ...
# 2392361  O1954914 2018-10-30 16:50:33        R10006  IN_STORE     0.0
# 2392362  O1241052 2018-07-08 10:47:37        R10001  IN_STORE     0.0
# 2392363    O28030 2018-01-05 17:07:01        R10005  IN_STORE     0.0
# 2392364   O277869 2018-02-12 11:18:33        R10005  IN_STORE     3.0
# 2392365   O773630 2018-04-24 17:19:51        R10007  IN_STORE     0.0
#
#          COOKIES MAIN BASE SIDE_1 SIDE_2
# 0            2.0  NaN  NaN    NaN    NaN
# 1            0.0  NaN  NaN    NaN    NaN
# ...

# %%
#extract weekday from date
df_orders['Day_of_Week'] = pd.to_datetime(df_orders['DATETIME'], format='%m/%d/%y').dt.weekday_name
df_orders
# Out:
#          ORDER_ID            DATETIME RESTAURANT_ID      TYPE  DRINKS  \
# 0        O2226026 2018-12-07 19:17:45        R10001    PICKUP     2.0
# 1        O1279827 2018-07-14 21:23:43        R10006  IN_STORE     0.0
# 2         O689957 2018-04-12 13:14:42        R10002    PICKUP     0.0
# 3        O1497863 2018-08-21 18:14:23        R10007  IN_STORE     1.0
# 4        O1443303 2018-08-12 18:04:44        R10006  DELIVERY     0.0
# ...           ...                 ...           ...       ...     ...
# 2392361  O1954914 2018-10-30 16:50:33        R10006  IN_STORE     0.0
# 2392362  O1241052 2018-07-08 10:47:37        R10001  IN_STORE     0.0
# 2392363    O28030 2018-01-05 17:07:01        R10005  IN_STORE     0.0
# 2392364   O277869 2018-02-12 11:18:33        R10005  IN_STORE     3.0
# 2392365   O773630 2018-04-24 17:19:51        R10007  IN_STORE     0.0
#
#          COOKIES MAIN BASE SIDE_1 SIDE_2 Day_of_Week
# 0            2.0  NaN  NaN    NaN    NaN      Friday
# ...

# %%
#Extract YEAR
df_orders['DATETIME'].dt.year
# Out:
# 0          2018
# 1          2018
# 2          2018
# 3          2018
# 4          2018
#            ...
# 2392361    2018
# 2392362    2018
# 2392363    2018
# 2392364    2018
# 2392365    2018
# Name: DATETIME, Length: 2392366, dtype: int64

# %%
#Extract MONTH
df_orders['DATETIME'].dt.month
# Out:
# 0          12
# 1           7
# 2           4
# 3           8
# 4           8
#            ..
# 2392361    10
# 2392362     7
# 2392363     1
# 2392364     2
# 2392365     4
# Name: DATETIME, Length: 2392366, dtype: int64

# %%
df_orders['Year'] = df_orders['DATETIME'].dt.year
df_orders['Month'] = df_orders['DATETIME'].dt.month
df_orders
# Out:
#          ORDER_ID            DATETIME RESTAURANT_ID      TYPE  DRINKS  \
# 0        O2226026 2018-12-07 19:17:45        R10001    PICKUP     2.0
# 1        O1279827 2018-07-14 21:23:43        R10006  IN_STORE     0.0
# 2         O689957 2018-04-12 13:14:42        R10002    PICKUP     0.0
# 3        O1497863 2018-08-21 18:14:23        R10007  IN_STORE     1.0
# 4        O1443303 2018-08-12 18:04:44        R10006  DELIVERY     0.0
# ...           ...                 ...           ...       ...     ...
# 2392361  O1954914 2018-10-30 16:50:33        R10006  IN_STORE     0.0
# 2392362  O1241052 2018-07-08 10:47:37        R10001  IN_STORE     0.0
# 2392363    O28030 2018-01-05 17:07:01        R10005  IN_STORE     0.0
# 2392364   O277869 2018-02-12 11:18:33        R10005  IN_STORE     3.0
# 2392365   O773630 2018-04-24 17:19:51        R10007  IN_STORE     0.0
#
#          COOKIES MAIN BASE SIDE_1 SIDE_2 Day_of_Week  Year  Month        Date
# ...

# %%
#Extract DATE
from datetime import date
df_orders['Date'] = df_orders['DATETIME'].dt.strftime("%Y/%m/%d")
df_orders
# Out:
#          ORDER_ID            DATETIME RESTAURANT_ID      TYPE  DRINKS  \
# 0        O2226026 2018-12-07 19:17:45        R10001    PICKUP     2.0
# 1        O1279827 2018-07-14 21:23:43        R10006  IN_STORE     0.0
# 2         O689957 2018-04-12 13:14:42        R10002    PICKUP     0.0
# 3        O1497863 2018-08-21 18:14:23        R10007  IN_STORE     1.0
# 4        O1443303 2018-08-12 18:04:44        R10006  DELIVERY     0.0
# ...           ...                 ...           ...       ...     ...
# 2392361  O1954914 2018-10-30 16:50:33        R10006  IN_STORE     0.0
# 2392362  O1241052 2018-07-08 10:47:37        R10001  IN_STORE     0.0
# 2392363    O28030 2018-01-05 17:07:01        R10005  IN_STORE     0.0
# 2392364   O277869 2018-02-12 11:18:33        R10005  IN_STORE     3.0
# 2392365   O773630 2018-04-24 17:19:51        R10007  IN_STORE     0.0
#
#          COOKIES MAIN BASE SIDE_1 SIDE_2 Day_of_Week  Year  Month        Date
# ...

# %%
df_orders['Day_of_Week'].value_counts().plot(kind = 'bar')

# %%
df_orders['Day_of_Week'].value_counts()
# Out:
# Friday       370139
# Tuesday      367208
# Wednesday    366717
# Thursday     366376
# Monday       362317
# Sunday       280731
# Saturday     278878
# Name: Day_of_Week, dtype: int64

# %%
(df_orders.Date == '2018/06/01').sum()
# Out:
# 6759

# %%
df_orders['Date'].value_counts()
# Out:
# 2018/11/26    7939
# 2018/12/21    7871
# 2018/11/19    7852
# 2018/11/07    7844
# 2018/11/09    7830
#               ...
# 2018/01/01    4376
# 2018/07/14    4362
# 2018/07/04    4240
# 2018/06/30    4191
# 2018/07/01    4147
# Name: Date, Length: 365, dtype: int64

# %%
add line

# %%
df_orders['Date'].value_counts()

# %%
df_orders['Date'].value_counts()

# %%
df_orders['Date'].value_counts()
